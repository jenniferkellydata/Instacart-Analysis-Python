# %%
Contents
1.Importing libaries
2. Importing data
3. Merging data sets
df_merged = df_orders_products_combined.merge

# %% [markdown]
# 01. Importing libraries

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 02. Importing data

# %%
#Importing data
df_orders_products_combined = pd.read_pickle(r'C:\Users\kelly\OneDrive\Desktop\Prepared Data\orders_products_combined.pkl')

# %%
df_orders_products_combined.shape
# Out:
# (30356421, 13)

# %%
#Importing data
df_products_checked = pd.read_csv(r'C:\Users\kelly\OneDrive\Desktop\Prepared Data\products_checked.csv', index_col = False)

# %%
df_orders_products_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    1           1   2398795  2398795    prior             2
# 1                    1           1   2398795  2398795    prior             2
# 2                    1           1   2398795  2398795    prior             2
# 3                    1           1   2398795  2398795    prior             2
# 4                    1           1   2398795  2398795    prior             2
# ...                ...         ...       ...      ...      ...           ...
# 30356416       3421081     3421081   2977660  2977660    prior            13
# 30356417       3421081     3421081   2977660  2977660    prior            13
# 30356418       3421081     3421081   2977660  2977660    prior            13
# 30356419       3421081     3421081   2977660  2977660    prior            13
# 30356420       3421081     3421081   2977660  2977660    prior            13
#
# ...

# %%
df_products_checked
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Merging data sets
df_merged = df_orders_products_combined.merge(df_products_checked, on = 'product_id')

# %%
#Merged results
df_merged
# Out:
#           Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  \
# 0                    1             1   2398795  2398795    prior
# 1                    2             2    473747   473747    prior
# 2                    3             3   2254736  2254736    prior
# 3                    4             4    431534   431534    prior
# 4                    5             5   3367565  3367565    prior
# ...                ...           ...       ...      ...      ...
# 30328758       3360494       3360494     31526    31526    prior
# 30328759       3376039       3376039   2745165  2745165    prior
# 30328760       3388472       3388472    850996   850996    prior
# 30328761       3392718       3392718   2550789  2550789    prior
# 30328762       3395727       3395727   2518919  2518919    prior
#
#           order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0                    2          3                  7                    15.0
# ...

# %%
df_merged.to_pickle(r'C:\Users\kelly\OneDrive\Desktop\Prepared Data/orders_products_merged.pickle')
